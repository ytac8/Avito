# %%
import pandas as pd

# %%
train = pd.read_csv('../data/unzipped/train.csv')
test = pd.read_csv('../data/unzipped/test.csv')

# %%
train_image_feature = pd.read_hdf('../src/imageNet/train_image_feature.h5', 'table')

# %%
test_image_feature = pd.read_hdf('../src/imageNet/test_image_feature.h5', 'table')

# %%
merged = train.merge(train_image_feature, on='item_id', how='left')

# %%
concated = pd.concat([train,train_image_feature ],axis=1)

# %%
concated
# Out:
#               item_id       user_id                   region  \
# 0        b912c3c6a6ad  e00f8ff2eaf9     Свердловская область
# 1        2dac0150717d  39aeb48f0017        Самарская область
# 2        ba83aefab5dc  91e2f88dd6e3       Ростовская область
# 3        02996f1dd2ea  bf5cccea572d                Татарстан
# 4        7c90be56d2ab  ef50846afc0b    Волгоградская область
# 5        51e0962387f7  bbfad0b1ad0a                Татарстан
# 6        c4f260a2b48a  08f469d2e6f7    Нижегородская область
# 7        6b71309d6a8a  fef86baa002c            Пермский край
# 8        c5b969cb63a2  055825270190     Оренбургская область
# 9        b1570962e68c  f9e8f831d94c    Нижегородская область
# 10       d5480bb4a6e4  d46200940f37      Ханты-Мансийский АО
# 11       86f41f50d8c1  35c2b6b654e0        Тюменская область
# 12       645237cb3601  fc9a38b79414     Оренбургская область
# 13       df2116f34563  3ce3c2318b16       Ростовская область
# ...

# %%
train_image_feature
# Out:
#                 0         1         2         3         4         5         6  \
# 0        0.180517  0.041181  0.304268  0.082899  0.036899  0.066899  0.007919
# 1        0.063185  0.352419  0.049253  0.073016  0.110211  0.036458  0.096885
# 2        0.015631  0.290990  0.020220  0.015682  0.450056  0.312280  0.070401
# 3        0.226242  0.043688  0.011595  0.046871  0.239974  0.055392  0.074829
# 4        0.083438  0.182263  0.046116  0.289482  0.013117  0.033964  0.213102
# 5        0.651008  0.108853  0.174105  0.287570  0.081451  0.094979  0.119915
# 6        0.230175  0.040988  0.146841  0.000117  0.060313  0.020165  0.001978
# 7        0.255270  0.000000  0.006336  0.006304  0.169666  0.229114  0.000030
# 8        0.320459  0.000000  0.190699  0.169344  0.203451  0.264597  0.059397
# 9        0.237863  0.017531  0.370935  0.058963  0.127117  0.125792  0.013388
# 10       0.147978  0.000088  0.037212  0.302921  0.155307  0.045950  0.018704
# ...
